# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split


wine=pd.read_csv("winequality-red.csv",sep=";")

X=wine.drop("quality",axis=1).values 
y=wine["quality"].values 
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)


scores=[]
alphas=[0.01,1.0,10.0,20.0,50.0]

for alpha in alphas:
    lasso=Lasso(alpha=alpha)
    lasso.fit(X_train,y_train)
    lasso_pred=lasso.predict(X_test)
    scores.append(lasso.score(X_test,y_test))
print("R-squared scores for different alpha values:",scores)
# Out:
# R-squared scores for different alpha values: [0.3177420410519234, 0.01764302094584813, -0.0034495046252929207, -0.0034495046252929207, -0.0034495046252929207]

# %%
names=wine.drop("quality",axis=1).columns 
lasso=Lasso(alpha=0.1)
lasso.fit(X,y)
lasso_coefs=lasso.coef_

# %%
plt.figure(figsize=(10,6))
plt.bar(names,lasso_coefs)
plt.xlabel("Features")
plt.ylabel("Lasso Coefficients")
plt.title("Feature Importance with Lasso Regression (alpha=0.1)")
plt.xticks(rotation=45)
plt.show()
