# %% [markdown]
# <h2>Done By Muhammad Irtaza Ali (55)</h2>

# %% [markdown]
# <h3>Section 3: Data Grouping
# </h3>

# %%
#Section 3
import pandas as pd
df=pd.read_csv("winequality-white.csv",sep=";")
df
# Out:
# Type:        module
# String form: <module 'pandas' from 'D:\\anacoda\\Lib\\site-packages\\pandas\\__init__.py'>
# File:        d:\anacoda\lib\site-packages\pandas\__init__.py
# Docstring:
# pandas - a powerful data analysis and manipulation library for Python
# ...
#
# **pandas** is a Python package providing fast, flexible, and expressive data
# structures designed to make working with "relational" or "labeled" data both
# easy and intuitive. It aims to be the fundamental high-level building block for
# doing practical, **real world** data analysis in Python. Additionally, it has
# the broader goal of becoming **the most powerful and flexible open source data
# analysis / manipulation tool available in any language**. It is already well on
# its way toward this goal.
#
# Main Features
# -------------
# Here are just a few of the things that pandas does well:
#
#   - Easy handling of missing data in floating point as well as non-floating
#     point data.
# ...

# %% [markdown]
# <h3>Group wines by quality rating and calculate the mean alcohol content.</h3>

# %%
g=df.groupby("quality")
g["alcohol"].mean()
#for quality,data in g:
 #   print(quality,data)
# Out:
# quality
# 3    10.345000
# 4    10.152454
# 5     9.808840
# 6    10.575372
# 7    11.367936
# 8    11.636000
# 9    12.180000
# Name: alcohol, dtype: float64

# %% [markdown]
# <h3>Group wines by pH level (acidic, neutral,
# basic) and calculate the mean quality
# rating.
# </h3>

# %%
g=df.groupby("pH")
g["quality"].mean()
# Out:
# pH
# 2.72    6.000000
# 2.74    6.000000
# 2.77    6.000000
# 2.79    5.000000
# 2.80    5.666667
#           ...
# 3.77    5.000000
# 3.79    5.000000
# 3.80    6.000000
# 3.81    6.000000
# 3.82    7.000000
# Name: quality, Length: 103, dtype: float64

# %% [markdown]
# <h3>Section 4: Data Sorting
# • Sort wines by quality rating in
# descending order.
# </h3>

# %%
# section 4 task
df.sort_values("quality",ascending=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 827             7.4              0.24         0.36            2.00      0.031
# 1605            7.1              0.26         0.49            2.20      0.032
# 876             6.9              0.36         0.34            4.20      0.018
# 774             9.1              0.27         0.45           10.60      0.035
# 820             6.6              0.36         0.29            1.60      0.021
# ...             ...               ...          ...             ...        ...
# 1484            7.5              0.32         0.24            4.60      0.053
# 2373            7.6              0.48         0.37            1.20      0.034
# 251             8.5              0.26         0.21           16.20      0.074
# 1688            6.7              0.25         0.26            1.55      0.041
# 253             5.8              0.24         0.44            3.50      0.029
#
# ...

# %% [markdown]
# <h3>Sort wines by alcohol content in
# ascending order.</h3>

# %%
df.sort_values("alcohol")
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3265            4.2             0.215         0.23            5.10      0.041
# 2625            4.5             0.190         0.21            0.95      0.033
# 3839            6.2             0.310         0.23            3.30      0.052
# 4020            6.4             0.370         0.12            5.90      0.056
# 3835            6.2             0.310         0.23            3.30      0.052
# ...             ...               ...          ...             ...        ...
# 3904            5.0             0.455         0.18            1.90      0.036
# 2945            4.9             0.330         0.31            1.20      0.016
# 1099            5.8             0.290         0.21            2.60      0.025
# 4503            5.8             0.610         0.01            8.40      0.041
# 3918            6.4             0.350         0.28            1.60      0.037
#
# ...

# %% [markdown]
# <h3>Section 5: Data Concatenation
#  Concatenate the red wine dataset with the white wine dataset</h3>

# %%
#Section 5
df1=pd.read_csv("winequality-red.csv",sep=";")
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
combine_wine = pd.concat([df,df1],ignore_index=True)
display(combine_wine)
combine_wine.to_csv("combine_wine.csv",index=False)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# <h2>The END</h2>
